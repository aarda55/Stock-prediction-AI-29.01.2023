# %%
#reads dataset (TSLA)
import pandas as pd

data = pd.read_csv('TSLA.csv')

data
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2010-06-29    1.266667    1.666667    1.169333    1.592667    1.592667
# 1     2010-06-30    1.719333    2.028000    1.553333    1.588667    1.588667
# 2     2010-07-01    1.666667    1.728000    1.351333    1.464000    1.464000
# 3     2010-07-02    1.533333    1.540000    1.247333    1.280000    1.280000
# 4     2010-07-06    1.333333    1.333333    1.055333    1.074000    1.074000
# ...          ...         ...         ...         ...         ...         ...
# 3197  2023-03-13  167.460007  177.350006  163.910004  174.479996  174.479996
# 3198  2023-03-14  177.309998  183.800003  177.139999  183.259995  183.259995
# 3199  2023-03-15  180.800003  182.339996  176.029999  180.449997  180.449997
# 3200  2023-03-16  180.369995  185.809998  178.839996  184.130005  184.130005
# 3201  2023-03-17  184.520004  186.220001  177.330002  180.130005  180.130005
#
#          Volume
# 0     281494500
# 1     257806500
# 2     123282000
# 3      77097000
# 4     103003500
# ...         ...
# 3197  167790300
# 3198  143717900
# 3199  145995600
# 3200  121136800
# 3201  132936600
#
# [3202 rows x 7 columns]

# %%
#unnecessary data is discarded
data = data[['Date' , 'Close']]

data
# Out:
#             Date       Close
# 0     2010-06-29    1.592667
# 1     2010-06-30    1.588667
# 2     2010-07-01    1.464000
# 3     2010-07-02    1.280000
# 4     2010-07-06    1.074000
# ...          ...         ...
# 3197  2023-03-13  174.479996
# 3198  2023-03-14  183.259995
# 3199  2023-03-15  180.449997
# 3200  2023-03-16  184.130005
# 3201  2023-03-17  180.130005
#
# [3202 rows x 2 columns]

# %%
#datetime is formatted from string to actual datetime
import datetime 

def string_to_time(s):
  split = s.split('-')
  year, month, day = int(split[0]), int(split[1]), int(split[2])
  return datetime.datetime(year=year, month=month, day=day)

datetime_object = string_to_time('2010-06-29')
datetime_object
# Out:
# datetime.datetime(2010, 6, 29, 0, 0)

# %%
data['Date'] = data['Date'].apply(string_to_time)
data['Date']
# Out:
# <ipython-input-29-3cbaaaadd3e0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Date'] = data['Date'].apply(string_to_time)
# 0      2010-06-29
# 1      2010-06-30
# 2      2010-07-01
# 3      2010-07-02
# 4      2010-07-06
#           ...
# 3197   2023-03-13
# 3198   2023-03-14
# 3199   2023-03-15
# 3200   2023-03-16
# 3201   2023-03-17
# Name: Date, Length: 3202, dtype: datetime64[ns]

# %%
#sets datetime as index
data.index = data.pop('Date')
data
# Out:
#                  Close
# Date
# 2010-06-29    1.592667
# 2010-06-30    1.588667
# 2010-07-01    1.464000
# 2010-07-02    1.280000
# 2010-07-06    1.074000
# ...                ...
# 2023-03-13  174.479996
# 2023-03-14  183.259995
# 2023-03-15  180.449997
# 2023-03-16  184.130005
# 2023-03-17  180.130005
#
# [3202 rows x 1 columns]

# %%
#simple vizualisation
import matplotlib.pyplot as plt

plt.plot(data.index, data['Close'])

# %%
#formats data in LTSM friendly format and cuts most of data out for performance reasons

import numpy as np

def data_to_windowed_data(dataframe, first_date_str, last_date_str, n=3):
  first_date = string_to_time(first_date_str)
  last_date  = string_to_time(last_date_str)

  target_date = first_date
  
  dates = []
  X, Y = [], []

  last_time = False
  while True:
    data_subset = dataframe.loc[:target_date].tail(n+1)
    
    if len(data_subset) != n+1:
      print(f'Error: Window of size {n} is too large for date {target_date}')
      return

    values = data_subset['Close'].to_numpy()
    x, y = values[:-1], values[-1]

    dates.append(target_date)
    X.append(x)
    Y.append(y)

    next_week = dataframe.loc[target_date:target_date+datetime.timedelta(days=7)]
    next_datetime_str = str(next_week.head(2).tail(1).index.values[0])
    next_date_str = next_datetime_str.split('T')[0]
    year_month_day = next_date_str.split('-')
    year, month, day = year_month_day
    next_date = datetime.datetime(day=int(day), month=int(month), year=int(year))
    
    if last_time:
      break
    
    target_date = next_date

    if target_date == last_date:
      last_time = True
    
  ret_data = pd.DataFrame({})
  ret_data['Target Date'] = dates
  
  X = np.array(X)
  for i in range(0, n):
    X[:, i]
    ret_data[f'Target-{n-i}'] = X[:, i]
  
  ret_data['Target'] = Y

  return ret_data

windowed_data = data_to_windowed_data(data, 
                                '2018-06-07', 
                                '2023-01-27', 
                                n=3)
windowed_data
# Out:
#      Target Date    Target-3    Target-2    Target-1      Target
# 0     2018-06-07   19.782667   19.408667   21.299999   21.072666
# 1     2018-06-08   19.408667   21.299999   21.072666   21.177334
# 2     2018-06-11   21.299999   21.072666   21.177334   22.139999
# 3     2018-06-12   21.072666   21.177334   22.139999   22.851334
# 4     2018-06-13   21.177334   22.139999   22.851334   22.985332
# ...          ...         ...         ...         ...         ...
# 1164  2023-01-23  128.779999  127.169998  133.419998  143.750000
# 1165  2023-01-24  127.169998  133.419998  143.750000  143.889999
# 1166  2023-01-25  133.419998  143.750000  143.889999  144.429993
# 1167  2023-01-26  143.750000  143.889999  144.429993  160.270004
# 1168  2023-01-27  143.889999  144.429993  160.270004  177.899994
#
# [1169 rows x 5 columns]

# %%
#formats data, so its usable with tensorflow
def windowed_data_to_date_X_y(windowed_dataframe):
  data_as_np = windowed_dataframe.to_numpy()

  dates = data_as_np[:, 0]

  middle_matrix = data_as_np[:, 1:-1]
  X = middle_matrix.reshape((len(dates), middle_matrix.shape[1], 1))

  Y = data_as_np[:, -1]

  return dates, X.astype(np.float32), Y.astype(np.float32)

dates, X, y = windowed_data_to_date_X_y(windowed_data)

dates.shape, X.shape, y.shape
# Out:
# ((1169,), (1169, 3, 1), (1169,))

# %%
#partitions data to Train, Validation and Test parts
part_80 = int(len(dates) * .8)
part_90 = int(len(dates) * .8)

dates_train, X_train, y_train = dates[:part_80], X[:part_80], y[:part_80]

dates_test, X_test, y_test = dates[part_90:], X[part_90:], y[part_90:]

plt.plot(dates_train, y_train)
plt.plot(dates_test, y_test)

plt.legend(['Train', 'Validation', 'Test'])

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers


#fitting the model
model = Sequential([layers.Input((3, 1)),
                    layers.LSTM(64),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(1)])

model.compile(loss='mse', 
              optimizer=Adam(learning_rate=0.001),
              metrics=['mean_absolute_error'])

#amount of epoches is manually optimized
model.fit(X_train, y_train, epochs=43)
# Out:
# Epoch 1/43
# 30/30 [==============================] - 3s 5ms/step - loss: 26011.8125 - mean_absolute_error: 114.1994
# Epoch 2/43
# 30/30 [==============================] - 0s 4ms/step - loss: 23904.1641 - mean_absolute_error: 104.3433
# Epoch 3/43
# 30/30 [==============================] - 0s 4ms/step - loss: 17835.8613 - mean_absolute_error: 92.2056
# Epoch 4/43
# 30/30 [==============================] - 0s 4ms/step - loss: 8777.4043 - mean_absolute_error: 56.4654
# Epoch 5/43
# 30/30 [==============================] - 0s 4ms/step - loss: 2723.8315 - mean_absolute_error: 24.6565
# Epoch 6/43
# 30/30 [==============================] - 0s 4ms/step - loss: 725.7141 - mean_absolute_error: 11.0788
# Epoch 7/43
# 30/30 [==============================] - 0s 4ms/step - loss: 314.1886 - mean_absolute_error: 7.8604
# Epoch 8/43
# 30/30 [==============================] - 0s 4ms/step - loss: 164.8692 - mean_absolute_error: 5.9374
# Epoch 9/43
# 30/30 [==============================] - 0s 5ms/step - loss: 116.3199 - mean_absolute_error: 5.5539
# Epoch 10/43
# 30/30 [==============================] - 0s 4ms/step - loss: 98.8871 - mean_absolute_error: 5.6014
# Epoch 11/43
# 30/30 [==============================] - 0s 5ms/step - loss: 102.5923 - mean_absolute_error: 5.9390
# Epoch 12/43
# 30/30 [==============================] - 0s 5ms/step - loss: 63.1435 - mean_absolute_error: 4.3755
# Epoch 13/43
# 30/30 [==============================] - 0s 4ms/step - loss: 73.5140 - mean_absolute_error: 5.0942
# Epoch 14/43
# 30/30 [==============================] - 0s 4ms/step - loss: 71.5655 - mean_absolute_error: 4.9364
# Epoch 15/43
# 30/30 [==============================] - 0s 4ms/step - loss: 68.0949 - mean_absolute_error: 4.6940
# Epoch 16/43
# 30/30 [==============================] - 0s 5ms/step - loss: 63.9033 - mean_absolute_error: 5.2251
# Epoch 17/43
# 30/30 [==============================] - 0s 4ms/step - loss: 68.8848 - mean_absolute_error: 4.9939
# Epoch 18/43
# 30/30 [==============================] - 0s 5ms/step - loss: 54.0293 - mean_absolute_error: 4.1643
# Epoch 19/43
# 30/30 [==============================] - 0s 5ms/step - loss: 59.4974 - mean_absolute_error: 4.3211
# Epoch 20/43
# 30/30 [==============================] - 0s 9ms/step - loss: 52.1476 - mean_absolute_error: 4.0891
# Epoch 21/43
# 30/30 [==============================] - 0s 9ms/step - loss: 52.6102 - mean_absolute_error: 3.9664
# Epoch 22/43
# 30/30 [==============================] - 0s 9ms/step - loss: 89.6889 - mean_absolute_error: 5.6567
# Epoch 23/43
# 30/30 [==============================] - 0s 9ms/step - loss: 71.4837 - mean_absolute_error: 4.9680
# Epoch 24/43
# 30/30 [==============================] - 0s 7ms/step - loss: 56.0949 - mean_absolute_error: 4.2345
# Epoch 25/43
# 30/30 [==============================] - 0s 11ms/step - loss: 54.5958 - mean_absolute_error: 4.0878
# Epoch 26/43
# 30/30 [==============================] - 0s 9ms/step - loss: 56.0232 - mean_absolute_error: 4.2342
# Epoch 27/43
# 30/30 [==============================] - 0s 7ms/step - loss: 54.2308 - mean_absolute_error: 4.2658
# Epoch 28/43
# 30/30 [==============================] - 0s 6ms/step - loss: 48.4430 - mean_absolute_error: 3.8196
# Epoch 29/43
# 30/30 [==============================] - 0s 7ms/step - loss: 44.4838 - mean_absolute_error: 3.6633
# Epoch 30/43
# 30/30 [==============================] - 0s 9ms/step - loss: 48.2103 - mean_absolute_error: 3.7993
# Epoch 31/43
# 30/30 [==============================] - 0s 12ms/step - loss: 55.6418 - mean_absolute_error: 4.2431
# Epoch 32/43
# 30/30 [==============================] - 0s 11ms/step - loss: 47.8081 - mean_absolute_error: 3.9345
# Epoch 33/43
# 30/30 [==============================] - 0s 8ms/step - loss: 48.1860 - mean_absolute_error: 3.8563
# Epoch 34/43
# 30/30 [==============================] - 0s 8ms/step - loss: 47.3638 - mean_absolute_error: 3.9295
# Epoch 35/43
# 30/30 [==============================] - 0s 7ms/step - loss: 52.0149 - mean_absolute_error: 4.3293
# Epoch 36/43
# 30/30 [==============================] - 0s 8ms/step - loss: 48.7200 - mean_absolute_error: 4.0684
# Epoch 37/43
# 30/30 [==============================] - 0s 8ms/step - loss: 70.8030 - mean_absolute_error: 4.9798
# Epoch 38/43
# 30/30 [==============================] - 0s 9ms/step - loss: 57.4207 - mean_absolute_error: 4.2682
# Epoch 39/43
# 30/30 [==============================] - 0s 7ms/step - loss: 49.7306 - mean_absolute_error: 4.0677
# Epoch 40/43
# 30/30 [==============================] - 0s 8ms/step - loss: 51.0856 - mean_absolute_error: 3.8240
# Epoch 41/43
# 30/30 [==============================] - 0s 7ms/step - loss: 54.4883 - mean_absolute_error: 4.4735
# Epoch 42/43
# 30/30 [==============================] - 0s 8ms/step - loss: 70.5819 - mean_absolute_error: 5.0318
# Epoch 43/43
# 30/30 [==============================] - 0s 8ms/step - loss: 49.6099 - mean_absolute_error: 3.9247

# %%
#check for Train prediction precision
train_predictions = model.predict(X_train).flatten()

plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.legend(['Training Predictions', 'Training Observations'])
# Out:
# 30/30 [==============================] - 1s 2ms/step

# %%
#check for Test prediction precision
test_predictions = model.predict(X_test).flatten()

plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Testing Predictions', 'Testing Observations'])
# Out:
# 8/8 [==============================] - 0s 3ms/step

# %% [markdown]
# # ***`Test the model with Meta dataset`***

# %%
#reads dataset
import pandas as pd

data = pd.read_csv('META.csv')

data
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2012-05-18   42.049999   45.000000   38.000000   38.230000   38.230000
# 1     2012-05-21   36.529999   36.660000   33.000000   34.029999   34.029999
# 2     2012-05-22   32.610001   33.590000   30.940001   31.000000   31.000000
# 3     2012-05-23   31.370001   32.500000   31.360001   32.000000   32.000000
# 4     2012-05-24   32.950001   33.209999   31.770000   33.029999   33.029999
# ...          ...         ...         ...         ...         ...         ...
# 2720  2023-03-13  177.960007  183.779999  174.820007  180.899994  180.899994
# 2721  2023-03-14  187.580002  194.320007  186.559998  194.020004  194.020004
# 2722  2023-03-15  192.949997  197.779999  190.839996  197.750000  197.750000
# 2723  2023-03-16  198.259995  205.759995  196.089996  204.929993  204.929993
# 2724  2023-03-17  200.559998  201.899994  195.429993  195.610001  195.610001
#
#          Volume
# 0     573576400
# 1     168192700
# 2     101786600
# 3      73600000
# 4      50237200
# ...         ...
# 2720   24728000
# 2721   41642600
# 2722   42123600
# 2723   50447100
# 2724   50074800
#
# [2725 rows x 7 columns]

# %%
#useless data is discarded
data = data[['Date' , 'Close']]

data
# Out:
#             Date       Close
# 0     2012-05-18   38.230000
# 1     2012-05-21   34.029999
# 2     2012-05-22   31.000000
# 3     2012-05-23   32.000000
# 4     2012-05-24   33.029999
# ...          ...         ...
# 2720  2023-03-13  180.899994
# 2721  2023-03-14  194.020004
# 2722  2023-03-15  197.750000
# 2723  2023-03-16  204.929993
# 2724  2023-03-17  195.610001
#
# [2725 rows x 2 columns]

# %%
#datetime is formatted from string to actual datetime
import datetime 

def string_to_time(s):
  split = s.split('-')
  year, month, day = int(split[0]), int(split[1]), int(split[2])
  return datetime.datetime(year=year, month=month, day=day)

datetime_object = string_to_time('2010-06-29')
datetime_object
# Out:
# datetime.datetime(2010, 6, 29, 0, 0)

# %%
data['Date'] = data['Date'].apply(string_to_time)
data['Date']
# Out:
# <ipython-input-41-3cbaaaadd3e0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Date'] = data['Date'].apply(string_to_time)
# 0      2012-05-18
# 1      2012-05-21
# 2      2012-05-22
# 3      2012-05-23
# 4      2012-05-24
#           ...
# 2720   2023-03-13
# 2721   2023-03-14
# 2722   2023-03-15
# 2723   2023-03-16
# 2724   2023-03-17
# Name: Date, Length: 2725, dtype: datetime64[ns]

# %%
#set date as index
data.index = data.pop('Date')
data
# Out:
#                  Close
# Date
# 2012-05-18   38.230000
# 2012-05-21   34.029999
# 2012-05-22   31.000000
# 2012-05-23   32.000000
# 2012-05-24   33.029999
# ...                ...
# 2023-03-13  180.899994
# 2023-03-14  194.020004
# 2023-03-15  197.750000
# 2023-03-16  204.929993
# 2023-03-17  195.610001
#
# [2725 rows x 1 columns]

# %%
#plotting the values
import matplotlib.pyplot as plt

plt.plot(data.index, data['Close'])

# %%
#formats data in LTSM friendly format and cuts most of data out for performance reasons

import numpy as np

def data_to_windowed_data(dataframe, first_date_str, last_date_str, n=3):
  first_date = string_to_time(first_date_str)
  last_date  = string_to_time(last_date_str)

  target_date = first_date
  
  dates = []
  X, Y = [], []

  last_time = False
  while True:
    data_subset = dataframe.loc[:target_date].tail(n+1)
    
    if len(data_subset) != n+1:
      print(f'Error: Window of size {n} is too large for date {target_date}')
      return

    values = data_subset['Close'].to_numpy()
    x, y = values[:-1], values[-1]

    dates.append(target_date)
    X.append(x)
    Y.append(y)

    next_week = dataframe.loc[target_date:target_date+datetime.timedelta(days=7)]
    next_datetime_str = str(next_week.head(2).tail(1).index.values[0])
    next_date_str = next_datetime_str.split('T')[0]
    year_month_day = next_date_str.split('-')
    year, month, day = year_month_day
    next_date = datetime.datetime(day=int(day), month=int(month), year=int(year))
    
    if last_time:
      break
    
    target_date = next_date

    if target_date == last_date:
      last_time = True
    
  ret_data = pd.DataFrame({})
  ret_data['Target Date'] = dates
  
  X = np.array(X)
  for i in range(0, n):
    X[:, i]
    ret_data[f'Target-{n-i}'] = X[:, i]
  
  ret_data['Target'] = Y

  return ret_data

windowed_data = data_to_windowed_data(data, 
                                '2018-01-01', 
                                '2023-01-27', 
                                n=3)
windowed_data
# Out:
#      Target Date    Target-3    Target-2    Target-1      Target
# 0     2018-01-01  175.990005  177.619995  177.919998  176.460007
# 1     2018-01-03  177.919998  176.460007  181.419998  184.669998
# 2     2018-01-04  176.460007  181.419998  184.669998  184.330002
# 3     2018-01-05  181.419998  184.669998  184.330002  186.850006
# 4     2018-01-08  184.669998  184.330002  186.850006  188.279999
# ...          ...         ...         ...         ...         ...
# 1272  2023-01-23  133.020004  136.149994  139.369995  143.270004
# 1273  2023-01-24  136.149994  139.369995  143.270004  143.139999
# 1274  2023-01-25  139.369995  143.270004  143.139999  141.500000
# 1275  2023-01-26  143.270004  143.139999  141.500000  147.300003
# 1276  2023-01-27  143.139999  141.500000  147.300003  151.740005
#
# [1277 rows x 5 columns]

# %%
#formats data, so its usable with tensorflow
def windowed_data_to_date_X_y(windowed_dataframe):
  data_as_np = windowed_dataframe.to_numpy()

  dates = data_as_np[:, 0]

  middle_matrix = data_as_np[:, 1:-1]
  X = middle_matrix.reshape((len(dates), middle_matrix.shape[1], 1))

  Y = data_as_np[:, -1]

  return dates, X.astype(np.float32), Y.astype(np.float32)

dates, X, y = windowed_data_to_date_X_y(windowed_data)

dates.shape, X.shape, y.shape
# Out:
# ((1277,), (1277, 3, 1), (1277,))

# %%
#check for Train prediction precision
train_predictions = model.predict(X).flatten()

plt.plot(dates, train_predictions)
plt.plot(dates, y)
plt.legend(['predictions', 'Observations'])
# Out:
# 40/40 [==============================] - 0s 2ms/step

# %% [markdown]
# # ***`Test with Nasdaq`***

# %%
#reads dataset
import pandas as pd

data = pd.read_csv('^IXIC.csv')

data
# Out:
#              Date          Open          High           Low         Close  \
# 0      1971-02-05    100.000000    100.000000    100.000000    100.000000
# 1      1971-02-08    100.839996    100.839996    100.839996    100.839996
# 2      1971-02-09    100.760002    100.760002    100.760002    100.760002
# 3      1971-02-10    100.690002    100.690002    100.690002    100.690002
# 4      1971-02-11    101.449997    101.449997    101.449997    101.449997
# ...           ...           ...           ...           ...           ...
# 13138  2023-03-13  11041.459961  11326.730469  10982.799805  11188.839844
# 13139  2023-03-14  11357.730469  11467.019531  11284.929688  11428.150391
# 13140  2023-03-15  11291.169922  11447.900391  11238.440430  11434.049805
# 13141  2023-03-16  11384.870117  11733.799805  11365.490234  11717.280273
# 13142  2023-03-17  11696.339844  11773.110352  11562.629883  11630.509766
#
#           Adj Close      Volume
# 0        100.000000           0
# 1        100.839996           0
# 2        100.760002           0
# 3        100.690002           0
# 4        101.449997           0
# ...             ...         ...
# 13138  11188.839844  6201490000
# 13139  11428.150391  5533120000
# 13140  11434.049805  5912430000
# 13141  11717.280273  5498920000
# 13142  11630.509766  7903090000
#
# [13143 rows x 7 columns]

# %%
#useless data is discarded
data = data[['Date' , 'Close']]

data
# Out:
#              Date         Close
# 0      1971-02-05    100.000000
# 1      1971-02-08    100.839996
# 2      1971-02-09    100.760002
# 3      1971-02-10    100.690002
# 4      1971-02-11    101.449997
# ...           ...           ...
# 13138  2023-03-13  11188.839844
# 13139  2023-03-14  11428.150391
# 13140  2023-03-15  11434.049805
# 13141  2023-03-16  11717.280273
# 13142  2023-03-17  11630.509766
#
# [13143 rows x 2 columns]

# %%
#datetime is formatted from string to actual datetime
import datetime 

def string_to_time(s):
  split = s.split('-')
  year, month, day = int(split[0]), int(split[1]), int(split[2])
  return datetime.datetime(year=year, month=month, day=day)

datetime_object = string_to_time('2010-06-29')
datetime_object
# Out:
# datetime.datetime(2010, 6, 29, 0, 0)

# %%
data['Date'] = data['Date'].apply(string_to_time)
data['Date']
# Out:
# <ipython-input-52-3cbaaaadd3e0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Date'] = data['Date'].apply(string_to_time)
# 0       1971-02-05
# 1       1971-02-08
# 2       1971-02-09
# 3       1971-02-10
# 4       1971-02-11
#            ...
# 13138   2023-03-13
# 13139   2023-03-14
# 13140   2023-03-15
# 13141   2023-03-16
# 13142   2023-03-17
# Name: Date, Length: 13143, dtype: datetime64[ns]

# %%
#set datetime as index
data.index = data.pop('Date')
data
# Out:
#                    Close
# Date
# 1971-02-05    100.000000
# 1971-02-08    100.839996
# 1971-02-09    100.760002
# 1971-02-10    100.690002
# 1971-02-11    101.449997
# ...                  ...
# 2023-03-13  11188.839844
# 2023-03-14  11428.150391
# 2023-03-15  11434.049805
# 2023-03-16  11717.280273
# 2023-03-17  11630.509766
#
# [13143 rows x 1 columns]

# %%
#plot the data
import matplotlib.pyplot as plt

plt.plot(data.index, data['Close'])

# %%
#formats data in LTSM friendly format and cuts most of data out for performance reasons

import numpy as np

def data_to_windowed_data(dataframe, first_date_str, last_date_str, n=3):
  first_date = string_to_time(first_date_str)
  last_date  = string_to_time(last_date_str)

  target_date = first_date
  
  dates = []
  X, Y = [], []

  last_time = False
  while True:
    data_subset = dataframe.loc[:target_date].tail(n+1)
    
    if len(data_subset) != n+1:
      print(f'Error: Window of size {n} is too large for date {target_date}')
      return

    values = data_subset['Close'].to_numpy()
    x, y = values[:-1], values[-1]

    dates.append(target_date)
    X.append(x)
    Y.append(y)

    next_week = dataframe.loc[target_date:target_date+datetime.timedelta(days=7)]
    next_datetime_str = str(next_week.head(2).tail(1).index.values[0])
    next_date_str = next_datetime_str.split('T')[0]
    year_month_day = next_date_str.split('-')
    year, month, day = year_month_day
    next_date = datetime.datetime(day=int(day), month=int(month), year=int(year))
    
    if last_time:
      break
    
    target_date = next_date

    if target_date == last_date:
      last_time = True
    
  ret_data = pd.DataFrame({})
  ret_data['Target Date'] = dates
  
  X = np.array(X)
  for i in range(0, n):
    X[:, i]
    ret_data[f'Target-{n-i}'] = X[:, i]
  
  ret_data['Target'] = Y

  return ret_data

windowed_data = data_to_windowed_data(data, 
                                '2021-06-07', 
                                '2023-01-27', 
                                n=3)
windowed_data
# Out:
#     Target Date      Target-3      Target-2      Target-1        Target
# 0    2021-06-07  13756.330078  13614.509766  13814.490234  13881.719727
# 1    2021-06-08  13614.509766  13814.490234  13881.719727  13924.910156
# 2    2021-06-09  13814.490234  13881.719727  13924.910156  13911.750000
# 3    2021-06-10  13881.719727  13924.910156  13911.750000  14020.330078
# 4    2021-06-11  13924.910156  13911.750000  14020.330078  14069.419922
# ..          ...           ...           ...           ...           ...
# 410  2023-01-23  10957.009766  10852.269531  11140.429688  11364.410156
# 411  2023-01-24  10852.269531  11140.429688  11364.410156  11334.269531
# 412  2023-01-25  11140.429688  11364.410156  11334.269531  11313.360352
# 413  2023-01-26  11364.410156  11334.269531  11313.360352  11512.410156
# 414  2023-01-27  11334.269531  11313.360352  11512.410156  11621.709961
#
# [415 rows x 5 columns]

# %%
#formats data, so its usable with tensorflow
def windowed_data_to_date_X_y(windowed_dataframe):
  data_as_np = windowed_dataframe.to_numpy()

  dates = data_as_np[:, 0]

  middle_matrix = data_as_np[:, 1:-1]
  X = middle_matrix.reshape((len(dates), middle_matrix.shape[1], 1))

  Y = data_as_np[:, -1]

  return dates, X.astype(np.float32), Y.astype(np.float32)

dates, X, y = windowed_data_to_date_X_y(windowed_data)

dates.shape, X.shape, y.shape
# Out:
# ((415,), (415, 3, 1), (415,))

# %%
#prediction of the model (absolute fail)
t = model.predict(X).flatten()

plt.plot(dates, t)
plt.plot(dates, y)
plt.legend(['Predictions', 'Observations'])
# Out:
# 13/13 [==============================] - 0s 3ms/step

# %% [markdown]
# # ***`Test with Microsoft`***

# %%
#reads dataset
import pandas as pd

data = pd.read_csv('MSFT.csv')

data
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     1986-03-13    0.088542    0.101563    0.088542    0.097222    0.060657
# 1     1986-03-14    0.097222    0.102431    0.097222    0.100694    0.062823
# 2     1986-03-17    0.100694    0.103299    0.100694    0.102431    0.063907
# 3     1986-03-18    0.102431    0.103299    0.098958    0.099826    0.062281
# 4     1986-03-19    0.099826    0.100694    0.097222    0.098090    0.061198
# ...          ...         ...         ...         ...         ...         ...
# 9324  2023-03-13  247.399994  257.910004  245.729996  253.919998  253.919998
# 9325  2023-03-14  256.750000  261.070007  255.860001  260.790009  260.790009
# 9326  2023-03-15  259.980011  266.480011  259.209991  265.440002  265.440002
# 9327  2023-03-16  265.209991  276.559998  263.279999  276.200012  276.200012
# 9328  2023-03-17  278.260010  283.329987  276.320007  279.429993  279.429993
#
#           Volume
# 0     1031788800
# 1      308160000
# 2      133171200
# 3       67766400
# 4       47894400
# ...          ...
# 9324    33339700
# 9325    33620300
# 9326    46028000
# 9327    54768800
# 9328    69492200
#
# [9329 rows x 7 columns]

# %%
#useless data is discarded
data = data[['Date' , 'Close']]

data
# Out:
#             Date       Close
# 0     1986-03-13    0.097222
# 1     1986-03-14    0.100694
# 2     1986-03-17    0.102431
# 3     1986-03-18    0.099826
# 4     1986-03-19    0.098090
# ...          ...         ...
# 9324  2023-03-13  253.919998
# 9325  2023-03-14  260.790009
# 9326  2023-03-15  265.440002
# 9327  2023-03-16  276.200012
# 9328  2023-03-17  279.429993
#
# [9329 rows x 2 columns]

# %%
#datetime is formatted from string to actual datetime
import datetime 

def string_to_time(s):
  split = s.split('-')
  year, month, day = int(split[0]), int(split[1]), int(split[2])
  return datetime.datetime(year=year, month=month, day=day)

datetime_object = string_to_time('2010-06-29')
datetime_object
# Out:
# datetime.datetime(2010, 6, 29, 0, 0)

# %%
data['Date'] = data['Date'].apply(string_to_time)
data['Date']
# Out:
# <ipython-input-61-3cbaaaadd3e0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Date'] = data['Date'].apply(string_to_time)
# 0      1986-03-13
# 1      1986-03-14
# 2      1986-03-17
# 3      1986-03-18
# 4      1986-03-19
#           ...
# 9324   2023-03-13
# 9325   2023-03-14
# 9326   2023-03-15
# 9327   2023-03-16
# 9328   2023-03-17
# Name: Date, Length: 9329, dtype: datetime64[ns]

# %%
#sets the date as the index
data.index = data.pop('Date')
data
# Out:
#                  Close
# Date
# 1986-03-13    0.097222
# 1986-03-14    0.100694
# 1986-03-17    0.102431
# 1986-03-18    0.099826
# 1986-03-19    0.098090
# ...                ...
# 2023-03-13  253.919998
# 2023-03-14  260.790009
# 2023-03-15  265.440002
# 2023-03-16  276.200012
# 2023-03-17  279.429993
#
# [9329 rows x 1 columns]

# %%
#plot the data
import matplotlib.pyplot as plt

plt.plot(data.index, data['Close'])

# %%
#formats data in LTSM friendly format and cuts most of data out for performance reasons

import numpy as np

def data_to_windowed_data(dataframe, first_date_str, last_date_str, n=3):
  first_date = string_to_time(first_date_str)
  last_date  = string_to_time(last_date_str)

  target_date = first_date
  
  dates = []
  X, Y = [], []

  last_time = False
  while True:
    data_subset = dataframe.loc[:target_date].tail(n+1)
    
    if len(data_subset) != n+1:
      print(f'Error: Window of size {n} is too large for date {target_date}')
      return

    values = data_subset['Close'].to_numpy()
    x, y = values[:-1], values[-1]

    dates.append(target_date)
    X.append(x)
    Y.append(y)

    next_week = dataframe.loc[target_date:target_date+datetime.timedelta(days=7)]
    next_datetime_str = str(next_week.head(2).tail(1).index.values[0])
    next_date_str = next_datetime_str.split('T')[0]
    year_month_day = next_date_str.split('-')
    year, month, day = year_month_day
    next_date = datetime.datetime(day=int(day), month=int(month), year=int(year))
    
    if last_time:
      break
    
    target_date = next_date

    if target_date == last_date:
      last_time = True
    
  ret_data = pd.DataFrame({})
  ret_data['Target Date'] = dates
  
  X = np.array(X)
  for i in range(0, n):
    X[:, i]
    ret_data[f'Target-{n-i}'] = X[:, i]
  
  ret_data['Target'] = Y

  return ret_data

windowed_data = data_to_windowed_data(data, 
                                '2018-06-07', 
                                '2023-01-27', 
                                n=3)
windowed_data
# Out:
#      Target Date    Target-3    Target-2    Target-1      Target
# 0     2018-06-07  101.669998  102.190002  102.489998  100.879997
# 1     2018-06-08  102.190002  102.489998  100.879997  101.629997
# 2     2018-06-11  102.489998  100.879997  101.629997  101.050003
# 3     2018-06-12  100.879997  101.629997  101.050003  101.309998
# 4     2018-06-13  101.629997  101.050003  101.309998  100.849998
# ...          ...         ...         ...         ...         ...
# 1164  2023-01-23  235.809998  231.929993  240.220001  242.580002
# 1165  2023-01-24  231.929993  240.220001  242.580002  242.039993
# 1166  2023-01-25  240.220001  242.580002  242.039993  240.610001
# 1167  2023-01-26  242.580002  242.039993  240.610001  248.000000
# 1168  2023-01-27  242.039993  240.610001  248.000000  248.160004
#
# [1169 rows x 5 columns]

# %%
#formats data, so its usable with tensorflow
def windowed_data_to_date_X_y(windowed_dataframe):
  data_as_np = windowed_dataframe.to_numpy()

  dates = data_as_np[:, 0]

  middle_matrix = data_as_np[:, 1:-1]
  X = middle_matrix.reshape((len(dates), middle_matrix.shape[1], 1))

  Y = data_as_np[:, -1]

  return dates, X.astype(np.float32), Y.astype(np.float32)

dates, X, y = windowed_data_to_date_X_y(windowed_data)

dates.shape, X.shape, y.shape
# Out:
# ((1169,), (1169, 3, 1), (1169,))

# %%
#check for Test prediction precision
test_predictions = model.predict(X).flatten()

plt.plot(dates, test_predictions)
plt.plot(dates, y)
plt.legend(['Predictions', 'Observations'])
# Out:
# 37/37 [==============================] - 0s 3ms/step

# %% [markdown]
# # ***`Increased data through dummy values`***

# %%
#reads dataset with null values
import pandas as pd

data = pd.read_csv('MSFT 2.csv')

data
# Out:
#             Date      Open      High       Low     Close  Adj Close  \
# 0     1986-03-13  0.088542  0.101563  0.088542  0.097222   0.060657
# 1     1986-03-14  0.097222  0.102431  0.097222  0.100694   0.062823
# 2     1986-03-17  0.100694  0.103299  0.100694  0.102431   0.063907
# 3     1986-03-18  0.102431  0.103299  0.098958  0.099826   0.062281
# 4     1986-03-19  0.099826  0.100694  0.097222  0.098090   0.061198
# ...          ...       ...       ...       ...       ...        ...
# 9429  2023-06-26       NaN       NaN       NaN       NaN        NaN
# 9430  2023-06-27       NaN       NaN       NaN       NaN        NaN
# 9431  2023-06-28       NaN       NaN       NaN       NaN        NaN
# 9432  2023-06-29       NaN       NaN       NaN       NaN        NaN
# 9433  2023-06-30       NaN       NaN       NaN       NaN        NaN
#
#             Volume
# 0     1.031789e+09
# 1     3.081600e+08
# 2     1.331712e+08
# 3     6.776640e+07
# 4     4.789440e+07
# ...            ...
# 9429           NaN
# 9430           NaN
# 9431           NaN
# 9432           NaN
# 9433           NaN
#
# [9434 rows x 7 columns]

# %%
#useless data is discarded
data = data[['Date' , 'Close']]

data
# Out:
#             Date     Close
# 0     1986-03-13  0.097222
# 1     1986-03-14  0.100694
# 2     1986-03-17  0.102431
# 3     1986-03-18  0.099826
# 4     1986-03-19  0.098090
# ...          ...       ...
# 9429  2023-06-26       NaN
# 9430  2023-06-27       NaN
# 9431  2023-06-28       NaN
# 9432  2023-06-29       NaN
# 9433  2023-06-30       NaN
#
# [9434 rows x 2 columns]

# %%
#datetime is formatted from string to actual datetime
import datetime 

def string_to_time(s):
  split = s.split('-')
  year, month, day = int(split[0]), int(split[1]), int(split[2])
  return datetime.datetime(year=year, month=month, day=day)

datetime_object = string_to_time('2010-06-29')
datetime_object
# Out:
# datetime.datetime(2010, 6, 29, 0, 0)

# %%
data['Date'] = data['Date'].apply(string_to_time)
data['Date']
# Out:
# <ipython-input-70-3cbaaaadd3e0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Date'] = data['Date'].apply(string_to_time)
# 0      1986-03-13
# 1      1986-03-14
# 2      1986-03-17
# 3      1986-03-18
# 4      1986-03-19
#           ...
# 9429   2023-06-26
# 9430   2023-06-27
# 9431   2023-06-28
# 9432   2023-06-29
# 9433   2023-06-30
# Name: Date, Length: 9434, dtype: datetime64[ns]

# %%
#sets datetime as index
data.index = data.pop('Date')
data
# Out:
#                Close
# Date
# 1986-03-13  0.097222
# 1986-03-14  0.100694
# 1986-03-17  0.102431
# 1986-03-18  0.099826
# 1986-03-19  0.098090
# ...              ...
# 2023-06-26       NaN
# 2023-06-27       NaN
# 2023-06-28       NaN
# 2023-06-29       NaN
# 2023-06-30       NaN
#
# [9434 rows x 1 columns]

# %%
#inserts dummy values for the null values
import numpy
data = data.fillna(100)
data
# Out:
#                  Close
# Date
# 1986-03-13    0.097222
# 1986-03-14    0.100694
# 1986-03-17    0.102431
# 1986-03-18    0.099826
# 1986-03-19    0.098090
# ...                ...
# 2023-06-26  100.000000
# 2023-06-27  100.000000
# 2023-06-28  100.000000
# 2023-06-29  100.000000
# 2023-06-30  100.000000
#
# [9434 rows x 1 columns]

# %%
import matplotlib.pyplot as plt

plt.plot(data.index, data['Close'])

# %%
#formats data in LTSM friendly format and cuts most of data out for performance reasons

import numpy as np

def data_to_windowed_data(dataframe, first_date_str, last_date_str, n=3):
  first_date = string_to_time(first_date_str)
  last_date  = string_to_time(last_date_str)

  target_date = first_date
  
  dates = []
  X, Y = [], []

  last_time = False
  while True:
    data_subset = dataframe.loc[:target_date].tail(n+1)
    
    if len(data_subset) != n+1:
      print(f'Error: Window of size {n} is too large for date {target_date}')
      return

    values = data_subset['Close'].to_numpy()
    x, y = values[:-1], values[-1]

    dates.append(target_date)
    X.append(x)
    Y.append(y)

    next_week = dataframe.loc[target_date:target_date+datetime.timedelta(days=7)]
    next_datetime_str = str(next_week.head(2).tail(1).index.values[0])
    next_date_str = next_datetime_str.split('T')[0]
    year_month_day = next_date_str.split('-')
    year, month, day = year_month_day
    next_date = datetime.datetime(day=int(day), month=int(month), year=int(year))
    
    if last_time:
      break
    
    target_date = next_date

    if target_date == last_date:
      last_time = True
    
  ret_data = pd.DataFrame({})
  ret_data['Target Date'] = dates
  
  X = np.array(X)
  for i in range(0, n):
    X[:, i]
    ret_data[f'Target-{n-i}'] = X[:, i]
  
  ret_data['Target'] = Y

  return ret_data

windowed_data = data_to_windowed_data(data, 
                                '2023-01-27', 
                                '2023-06-30', 
                                n=3)
windowed_data
# Out:
#     Target Date    Target-3    Target-2    Target-1      Target
# 0    2023-01-27  242.039993  240.610001  248.000000  248.160004
# 1    2023-01-30  240.610001  248.000000  248.160004  242.710007
# 2    2023-01-31  248.000000  248.160004  242.710007  247.809998
# 3    2023-02-01  248.160004  242.710007  247.809998  252.750000
# 4    2023-02-02  242.710007  247.809998  252.750000  264.600006
# ..          ...         ...         ...         ...         ...
# 135  2023-06-26  100.000000  100.000000  100.000000  100.000000
# 136  2023-06-27  100.000000  100.000000  100.000000  100.000000
# 137  2023-06-28  100.000000  100.000000  100.000000  100.000000
# 138  2023-06-29  100.000000  100.000000  100.000000  100.000000
# 139  2023-06-30  100.000000  100.000000  100.000000  100.000000
#
# [140 rows x 5 columns]

# %%
#formats data, so its usable with tensorflow
def windowed_data_to_date_X_y(windowed_dataframe):
  data_as_np = windowed_dataframe.to_numpy()

  dates = data_as_np[:, 0]

  middle_matrix = data_as_np[:, 1:-1]
  X = middle_matrix.reshape((len(dates), middle_matrix.shape[1], 1))

  Y = data_as_np[:, -1]

  return dates, X.astype(np.float32), Y.astype(np.float32)

dates, X, y = windowed_data_to_date_X_y(windowed_data)

dates.shape, X.shape, y.shape
# Out:
# ((140,), (140, 3, 1), (140,))

# %%
#check for Test prediction precision (more of a fail)
test_predictions = model.predict(X).flatten()

plt.plot(dates, test_predictions)
plt.plot(dates, y)
plt.legend(['Predictions', 'Observations'])
# Out:
# 5/5 [==============================] - 0s 4ms/step
